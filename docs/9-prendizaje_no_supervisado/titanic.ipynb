# %% [markdown]
# javier- embarque, nombre
# oscar- cabina, edad
# tracy - titulo
# fabian - precio
#
# --
#
# Survived,
# Pclass,
# Name,
# Sex,
# Age,
# Siblings/Spouses Aboard,
# Parents/Children Aboard,
